# %% [markdown]
# # Cleaning csvs

# %%
from os import path
import os

import pandas as pd

# %%
os.makedirs('../data/output/', exist_ok=True)

# %% [markdown]
# ## Broward

# %%
broward = pd.read_csv('../data/input/foia/broward.csv')
characteristics = pd.read_csv('../data/intermediary/scorecard/characteristics/broward.csv')
equity = pd.read_csv('../data/intermediary/scorecard/equity/broward.csv')
keys = pd.read_csv('../data/intermediary/keys/broward.csv')

# %%
broward = broward.rename(columns={'SchoolName': 'school_name'})
broward = broward.merge(keys[['school_name', 'school_number']], on='school_name')

# %%
historical = pd.read_csv('../data/input/historical_attendance_1819.csv')
historical = historical[historical['DISTRICT #'] == keys.district_number[0]]
historical.columns

hist_columns = [
    'DAYS PRESENT', 
    'DAYS ABSENT', 
    'TOTAL DAYS', 
    '% PRESENT', 
    'AVERAGE DAILY ATTENDANCE', 
    'AVERAGE DAILY MEMBERSHIP'
]

for column in hist_columns:
    historical[column] = pd.to_numeric(historical[column].str.replace(',','').str.replace('%',''))
    
hist_columns.append("SCHOOL #")

# %%
historical_context = pd.merge(historical, equity, left_on="SCHOOL #", right_on="school_number")

historical_poverty = historical_context.groupby('poverty').sum()
historical_poverty['% PRESENT'] = historical_poverty['DAYS PRESENT'] / historical_poverty['TOTAL DAYS']
historical_poverty
# Out:
#                    DISTRICT #  SCHOOL #  DAYS PRESENT  DAYS ABSENT  \
# poverty
# High Poverty              348    132110       5242658       396615
# Low Poverty               348    232756      10748908       533463
# Mid-Range Poverty        1170    531094      29389570      2097240
#
#                    TOTAL DAYS  % PRESENT  AVERAGE DAILY ATTENDANCE  \
# poverty
# High Poverty          5639273   0.929669                     29126
# Low Poverty          11282371   0.952717                     59714
# Mid-Range Poverty    31486810   0.933393                    163280
#
#                    AVERAGE DAILY MEMBERSHIP  school_number  district_number
# poverty
# High Poverty                          31325         132110              348
# Low Poverty                           62680         232756              348
# Mid-Range Poverty                    174929         531094             1170

# %%
export = broward.groupby(['school_name', 'school_number']).sum()
export = export.reset_index()
export['covid.agg.enroll'] = export['Enrollment']
export['covid.agg.attend'] = export['Login']
export = export[['school_name', 'school_number', 'covid.agg.enroll', 'covid.agg.attend']]
export['covid.avg'] = export['covid.agg.attend'] / export['covid.agg.enroll'] * 100

# %%
historical = historical.rename(columns={
    "SCHOOL #":      "school_number",
    "DISTRICT #":    "district_number",
    "DISTRICT NAME": "district_name",
    "DAYS PRESENT":  "1819.agg.attend",
    "TOTAL DAYS":    "1819.agg.enroll"
})

historical['1819.avg'] = historical["1819.agg.attend"] / historical["1819.agg.enroll"] * 100

export_hist = historical[[
    "school_number",
    "district_number",
    "district_name",
    "1819.agg.attend",
    "1819.agg.enroll",
    "1819.avg"
]]

export = export.merge(export_hist, on='school_number')

# %%
export = export.merge(equity, on=['school_number', 'district_number'])
export = export.merge(characteristics[[
    'school_number',
    'school_type', 
    'grade'
]], on='school_number')

# %%
export
# Out:
#                                        school_name  school_number  \
# 0                            ANNABEL C. PERRY PK-8           1631
# 1                                    APOLLO MIDDLE           1791
# 2                          ATLANTIC TECHNICAL HIGH           2221
# 3                         ATLANTIC WEST ELEMENTARY           2511
# 4                                   ATTUCKS MIDDLE            343
# ..                                             ...            ...
# 213  WHISPERING PINES EXCEPTIONAL EDUCATION CENTER           1752
# 214                           WILLIAM DANDY MIDDLE           1071
# 215             WILLIAM T. MCFATTER TECHNICAL HIGH           1291
# 216                       WILTON MANORS ELEMENTARY            191
# 217                        WINSTON PARK ELEMENTARY           3091
#
#      covid.agg.enroll  covid.agg.attend  covid.avg  district_number  \
# 0                7381              6667  90.326514                6
# 1               15320             14050  91.710183                6
# 2                6622              6361  96.058593                6
# 3                6748              6071  89.967398                6
# 4                9040              8165  90.320796                6
# ..                ...               ...        ...              ...
# 213              1483               987  66.554282                6
# 214              9801              7960  81.216202                6
# 215              6688              6204  92.763158                6
# 216              6303              5773  91.591306                6
# 217             12168             11756  96.614070                6
#
#     district_name  1819.agg.attend  1819.agg.enroll   1819.avg  \
# 0         BROWARD           124508           131620  94.596566
# 1         BROWARD           237032           250084  94.780954
# 2         BROWARD           119041           123474  96.409770
# 3         BROWARD           120886           128444  94.115724
# 4         BROWARD           136578           143403  95.240685
# ..            ...              ...              ...        ...
# 213       BROWARD            35191            39577  88.917806
# 214       BROWARD           170472           173839  98.063150
# 215       BROWARD           106202           111249  95.463330
# 216       BROWARD           103377           108679  95.121413
# 217       BROWARD           206255           216995  95.050577
#
#                minority            poverty      title_i         school_type  \
# 0         High Minority       High Poverty      Title I  Combination School
# 1    Mid-Range Minority  Mid-Range Poverty      Title I       Middle School
# 2    Mid-Range Minority  Mid-Range Poverty  Non-Title I         High School
# 3         High Minority  Mid-Range Poverty      Title I   Elementary School
# 4    Mid-Range Minority  Mid-Range Poverty      Title I       Middle School
# ..                  ...                ...          ...                 ...
# 213  Mid-Range Minority  Mid-Range Poverty  Non-Title I  Combination School
# 214       High Minority       High Poverty      Title I       Middle School
# 215  Mid-Range Minority  Mid-Range Poverty  Non-Title I         High School
# 216  Mid-Range Minority  Mid-Range Poverty      Title I   Elementary School
# 217  Mid-Range Minority  Mid-Range Poverty      Title I   Elementary School
#
#                 grade
# 0                   B
# 1                   B
# 2                   A
# 3          C or below
# 4                   B
# ..                ...
# 213  Improvement Plan
# 214        C or below
# 215                 A
# 216                 A
# 217                 B
#
# [218 rows x 15 columns]

# %%
export.to_csv("../data/output/broward.csv", index=False)

# %% [markdown]
# ## Miami-Dade

# %%
miami = pd.read_csv('../data/input/foia/miami-dade.csv')
characteristics = pd.read_csv('../data/intermediary/scorecard/characteristics/miami-dade.csv')
equity = pd.read_csv('../data/intermediary/scorecard/equity/miami-dade.csv')
enrollment = pd.read_csv('../data/intermediary/scorecard/enrollment/miami-dade.csv')

# %%
df = miami.merge(enrollment, on='school_number')
df['total_students'] = pd.to_numeric(df['total_students'])

df['est_present'] = df['pct_present'] / 100.0 * df['total_students']

# %%
historical = pd.read_csv('../data/input/historical_attendance_1819.csv')
historical = historical[historical['DISTRICT NAME'] == 'MIAMI-DADE']
historical.columns

hist_columns = [
    'DAYS PRESENT',
    'TOTAL DAYS', 
    '% PRESENT',
]

for column in hist_columns:
    historical[column] = pd.to_numeric(historical[column].str.replace(',','').str.replace('%',''))
    
hist_columns.append("SCHOOL #")

# %%
historical = historical[hist_columns]
historical = historical.rename(columns={
    'TOTAL DAYS':'1819.agg.enroll',
    'DAYS PRESENT':'1819.agg.attend',
    '% PRESENT': '1819.avg',
    'SCHOOL #':'school_number'
})

# %%
export = df.groupby(['school_name', 'school_number']).sum()
export = export.reset_index()

# %%
export = export[['school_name', 'school_number', 'total_students', 'est_present']]
export = export.merge(characteristics, on="school_number")
export = export.merge(equity, on=["school_number", 'district_number'])

export = export[[
    "school_name",
    "school_number",
    "total_students",
    "est_present",
    "school_type",
    "grade",
    "charter",
    "alt_schl",
    "minority",
    "poverty",
    "title_i"]
]

export = export.merge(historical, on='school_number')

export = export.rename(columns={
    'total_students': 'covid.agg.enroll',
    'est_present': 'covid.agg.attend'
})

export['covid.avg'] = export['covid.agg.attend'] / export['covid.agg.enroll'] * 100

# %%
export.to_csv("../data/output/miami-dade.csv", index=False)
